# %%
#panda is one of the best library for structered data manipulation, reand and write operation

# %%
import pandas as pd

# %%
df = pd.read_excel(r'E:\data fsds\data fsds\Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)  # data frame is equilant to the table
# Out:
# pandas.core.frame.DataFrame

# %%
# read a data from different sheet

pd.read_excel(r'E:\data fsds\data fsds\Attribute DataSet.xlsx' , sheet_name='sharan')
# Out:
#    1212192089      Casual      Low        0    L Summer
# 0           2  1190380701  vintage     High  0.0      L
# 1           3   966005983    Brief  Average  4.6      L
# 2           4   876339541     cute      Low  4.5      M
# 3         497   532874347   Casual  Average  4.7      M
# 4         495   713391965   Casual      Low  4.7      M
# 5         496   722565148     Sexy      Low  4.3   free
# 6         497   532874347   Casual  Average  4.7      M
# 7         498   655464934   Casual      NaN  NaN    NaN

# %%
#  Header name
pd.read_excel(r'E:\data fsds\data fsds\Attribute DataSet.xlsx' , sheet_name='Sheet3', header = None)
# Out:
#      0          1       2        3    4     5
# 0  497  532874347  Casual  Average  4.7     M
# 1  495  713391965  Casual      Low  4.7     M
# 2  496  722565148    Sexy      Low  4.3  free
# 3  497  532874347  Casual  Average  4.7     M
# 4  498  655464934  Casual      NaN  NaN   NaN

# %%
# assigning column names
pd.read_excel(r'E:\data fsds\data fsds\Attribute DataSet.xlsx' , sheet_name='Sheet3', header = None, names=["A", "B","C","D","E","F"])
# Out:
#      A          B       C        D    E     F
# 0  497  532874347  Casual  Average  4.7     M
# 1  495  713391965  Casual      Low  4.7     M
# 2  496  722565148    Sexy      Low  4.3  free
# 3  497  532874347  Casual  Average  4.7     M
# 4  498  655464934  Casual      NaN  NaN   NaN

# %%
df.head(2)   # it show first 2 rows
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.tail()  # ut shows last 5 rows
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
df.tail(2)    #last 2 rows
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %% [raw]
# # data availble in csv formate,  seperated by comma(,)

# %%
# file was uploaded in directry so no need to give path

pd.read_csv(r'haberman.csv')
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv('haberman.csv', header = None, names= ['Age', "Patient's year of operation", 'Number of positive', 'Survival status'])
# Out:
#      Age  Patient's year of operation  Number of positive  Survival status
# 0     30                           64                   1                1
# 1     30                           62                   3                1
# 2     30                           65                   0                1
# 3     31                           59                   2                1
# 4     31                           65                   4                1
# ..   ...                          ...                 ...              ...
# 301   75                           62                   1                1
# 302   76                           67                   0                1
# 303   77                           65                   3                1
# 304   78                           65                   1                2
# 305   83                           58                   2                2
#
# [306 rows x 4 columns]

# %%
pd.read_csv("haberman1.csv", sep='@')  # delimeter seperator(sep)
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %% [markdown]
# # till now we have red the data from local repository

# %% [markdown]
# # Now lets read a data from git hub repo,
# to do so click on file and clik on raw/ conver into raw and copy the url link and paste in path

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/College.csv", header = None)
# Out:
#           0      1       2       3          4          5            6   \
# 0    Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad
# 1        Yes   1660    1232     721         23         52         2885
# 2        Yes   2186    1924     512         16         29         2683
# 3        Yes   1428    1097     336         22         50         1036
# 4        Yes    417     349     137         60         89          510
# ..       ...    ...     ...     ...        ...        ...          ...
# 773       No   2197    1515     543          4         26         3089
# 774      Yes   1959    1805     695         24         47         2849
# 775      Yes   2097    1915     695         34         61         2793
# 776      Yes  10705    2453    1317         95         99         5217
# 777      Yes   2989    1855     691         28         63         2988
#
#               7         8           9      10        11   12        13  \
# ...

# %% [markdown]
# # Read a data from wbsite, dtaformate is html

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
a =pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(a)
# Out:
# list

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
len(a)
# Out:
# 1

# %% [markdown]
# # read JSON file, also can read from online json viewer

# %%
pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js['user']
# Out:
# 0     {'login': 'ParfaitG', 'id': 13602663, 'node_id...
# 1     {'login': 'gvfarns', 'id': 3987806, 'node_id':...
# 2     {'login': 'fhopecc', 'id': 61467, 'node_id': '...
# 3     {'login': 'dataxerik', 'id': 15721311, 'node_i...
# 4     {'login': 'kouml', 'id': 23252616, 'node_id': ...
# 5     {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 6     {'login': 'behrenhoff', 'id': 1408034, 'node_i...
# 7     {'login': 'msilva-pass', 'id': 91082605, 'node...
# 8     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 9     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 10    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 11    {'login': 'rgommers', 'id': 98330, 'node_id': ...
# 12    {'login': 'asandeep', 'id': 1650682, 'node_id'...
# 13    {'login': 'mmiller-max', 'id': 59854849, 'node...
# 14    {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 15    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 16    {'login': 'VHElise', 'id': 1756220, 'node_id':...
# ...

# %%
js['user'][0]
# Out:
# {'login': 'ParfaitG',
#  'id': 13602663,
#  'node_id': 'MDQ6VXNlcjEzNjAyNjYz',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/13602663?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/ParfaitG',
#  'html_url': 'https://github.com/ParfaitG',
#  'followers_url': 'https://api.github.com/users/ParfaitG/followers',
#  'following_url': 'https://api.github.com/users/ParfaitG/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/ParfaitG/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/ParfaitG/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/ParfaitG/subscriptions',
#  'organizations_url': 'https://api.github.com/users/ParfaitG/orgs',
#  'repos_url': 'https://api.github.com/users/ParfaitG/repos',
#  'events_url': 'https://api.github.com/users/ParfaitG/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/ParfaitG/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %% [markdown]
# # converting to json,

# %%
df.to_json('test.json')   #'test.json' is new file name, saved in pwd

# %%
pwd
# Out:
# 'C:\\Users\\User\\python_practice_JN'

# %% [markdown]
# # saving a datvca in the farm of data frame

# %%
df.to_csv("E:\\test.csv",  index  = False)

# %% [raw]
#  Task:-
#  Mysql :
#     1, create a table attribute dataset and dress dataset
#     2, do a bulk load for these two table for respective dataset
#     3, read the dataset in pandas as a dataframe
#     4, convert attribute dataset in json format,
#     5, store this dataset into mangodb,
#     6, in sql task try to perform left join operation with attributes dataset    on column Dress id
#     7, write asql query to findout how many unique dress that we have  based on dress id
#     8, try to find out how many dress is having recommandation is zero
#     9, try to find out total dress id
#     10, try to find out a 3rd highest  most selling dress id
#
#  v
